# %%
# !nvidia-smi

# %%
# !apt-get update
# !apt-get install -y git git-lfs
# !git lfs install

# %%
# !git clone https://github.com/mayankkashyap05/Sparkkronos.git
# %cd Sparkkronos

# %%
# !git lfs ls-files
# !ls -lh models/kronos_base/model.safetensors

# %%
# !pip install -r requirements.txt

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
# !python -u multi_config_run.py

# %%
# !zip -r prediction.zip /content/Sparkkronos/analysis/predictions

# %%
from google.colab import files
files.download("prediction.zip")
